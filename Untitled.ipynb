# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
data = [['E001', 'M', 34, 123, 'Normal', 350],
['E002', 'F', 40, 114, 'Overweight', 450],
['E003', 'F', 37, 135, 'Obesity', 169],
['E004', 'M', 30, 139, 'Underweight', 189],
['E005', 'F', 44, 117, 'Underweight', 183],
['E006', 'M', 36, 121, 'Normal', 80],
['E007', 'M', 32, 133, 'Obesity', 166],
['E008', 'F', 26, 140, 'Normal', 120],
['E009', 'M', 32, 133, 'Normal', 75],
['E010', 'M', 36, 133, 'Overweight', 40],
['E011','M', 28, 125, 'Normal', 200],
['E012','M', 42, 145, 'Obesity', 300],
['E013','F', 35, 130, 'Normal', 150],
['E014','M', 31, 136, 'Underweight', 175],
['E012','F', 45, 118, 'Underweight', 190]]

# %% [markdown]
# # Attribute

# %%
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 'Age', 'Sales', 'BMI', 'Income'] )

# %% [markdown]
# # Plots

# %%
df.hist()
plt.show()

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
plt.bar(df['Age'], df['Income'])
plt.xlabel("Age")
plt.ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
plt.boxplot(df['Income'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20159e8d850>,
#   <matplotlib.lines.Line2D at 0x20159e8eba0>],
#  'caps': [<matplotlib.lines.Line2D at 0x20159e8e960>,
#   <matplotlib.lines.Line2D at 0x20159e8ee70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20159e8d4c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20159e8c3e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20159e8e090>],
#  'means': []}
